# %% [markdown]
# # LIBS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # IMPORT

# %%
# dados de 2022
first_path2022 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\1st_2022"
second_path2022 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\2nd_2022"

first_df_2022 = pd.read_csv(first_path2022)
second_df_2022 = pd.read_csv(first_path2022)

# %%
# dados de 2023
first_path2023 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\1st_2023"
second_path2023 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\2nd_2023"

first_df_2023 = pd.read_csv(first_path2023)
second_df_2023 = pd.read_csv(first_path2023)

# %%
# dados de 2024
first_path2024 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\1st_2024"
second_path2024 = "C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\2nd_2024"

first_df_2024 = pd.read_csv(first_path2024)
second_df_2024 = pd.read_csv(first_path2024)

# %%
# merge dos dados
list_df = [first_df_2022, second_df_2022, first_df_2023, second_df_2023, first_df_2024, second_df_2024]
df = pd.concat(list_df, axis=0)
df
# Out:
#         Unnamed: 0 NOME_DEPARTAMENTO           NOME_SECCIONAL  \
# 0                0             DECAP    DEL.SEC.8º SAO MATEUS
# 1                1             DECAP    DEL.SEC.8º SAO MATEUS
# 2                2             DECAP         DEL.SEC.5º LESTE
# 3                3             DECAP        DEL.SEC.1º CENTRO
# 4                4             DECAP        DEL.SEC.1º CENTRO
# ...            ...               ...                      ...
# 592386      592386           DEMACRO  DEL.SEC.TABOÃO DA SERRA
# 592387      592387           DEMACRO  DEL.SEC.TABOÃO DA SERRA
# 592388      592388           DEMACRO  DEL.SEC.TABOÃO DA SERRA
# 592389      592389           DEMACRO  DEL.SEC.TABOÃO DA SERRA
# 592390      592390           DEMACRO  DEL.SEC.TABOÃO DA SERRA
#
#                   NOME_DELEGACIA   CIDADE  NUM_BO  ANO_BO DATA_COMUNICACAO_BO  \
# 0             08ª DDM SAO MATEUS  S.PAULO  AC0851    2022          2022-01-13
# ...

# %% [markdown]
# # SAVE

# %% [markdown]
# df.to_csv("C:\\Users\\SAMSUNG\\OneDrive\\Documentos\\dados\\df")
